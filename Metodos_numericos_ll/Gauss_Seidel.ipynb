# %%
import numpy as np
from numpy import linalg as LA

def gauss_seidel(A,b,nmax,tol):
    L = np.tril(A)
    U = A-L
    n = len(b)
    x=np.zeros(n)
    k = 0
    error = 10
    
    while (k < nmax and tol < error):
        xnew = np.dot(LA.inv(L),b-np.dot(U,x))
        error = LA.norm(xnew-x)
        print( "-----------------")
        print("Solucion x para la iteracion k = %2d con error = %5.4f"%(k,error))
        print(xnew)
        x=xnew
        k += 1
    if k==nmax:
        print("maximo numero de iteraciones fue alcanzado. ")
        print("probablemente no hay convergencia")

# %%
A = np.array([[5.,-2.,3.],
             [-3.,8.,1.],
             [-3.,-1.,-6.]])
b = np.array([-1.,4.,0.])

# %%
gauss_seidel(A,b,10000,1e-5)
# Out:
# -----------------
# Solucion x para la iteracion k =  0 con error = 0.4706
# [-0.2         0.425       0.02916667]
# -----------------
# Solucion x para la iteracion k =  1 con error = 0.1827
# [-0.0475      0.47854167 -0.05600694]
# -----------------
# Solucion x para la iteracion k =  2 con error = 0.0922
# [ 0.02502083  0.51638368 -0.09857436]
# -----------------
# Solucion x para la iteracion k =  3 con error = 0.0514
# [ 0.06569809  0.53695858 -0.12234214]
# -----------------
# Solucion x para la iteracion k =  4 con error = 0.0284
# [ 0.08818872  0.54836354 -0.13548828]
# -----------------
# Solucion x para la iteracion k =  5 con error = 0.0157
# [ 0.10063838  0.55467543 -0.1427651 ]
# -----------------
# Solucion x para la iteracion k =  6 con error = 0.0087
# [ 0.10752923  0.5581691  -0.1467928 ]
# -----------------
# Solucion x para la iteracion k =  7 con error = 0.0048
# [ 0.11134332  0.56010284 -0.14902213]
# -----------------
# Solucion x para la iteracion k =  8 con error = 0.0027
# [ 0.11345442  0.56117317 -0.15025607]
# -----------------
# Solucion x para la iteracion k =  9 con error = 0.0015
# [ 0.11462291  0.5617656  -0.15093906]
# -----------------
# Solucion x para la iteracion k = 10 con error = 0.0008
# [ 0.11526967  0.56209351 -0.15131709]
# -----------------
# Solucion x para la iteracion k = 11 con error = 0.0005
# [ 0.11562766  0.56227501 -0.15152633]
# -----------------
# Solucion x para la iteracion k = 12 con error = 0.0003
# [ 0.1158258   0.56237547 -0.15164214]
# -----------------
# Solucion x para la iteracion k = 13 con error = 0.0001
# [ 0.11593547  0.56243107 -0.15170625]
# -----------------
# Solucion x para la iteracion k = 14 con error = 0.0001
# [ 0.11599618  0.56246185 -0.15174173]
# -----------------
# Solucion x para la iteracion k = 15 con error = 0.0000
# [ 0.11602978  0.56247888 -0.15176137]
# -----------------
# Solucion x para la iteracion k = 16 con error = 0.0000
# [ 0.11604837  0.56248831 -0.15177224]
# -----------------
# Solucion x para la iteracion k = 17 con error = 0.0000
# [ 0.11605867  0.56249353 -0.15177826]
# -----------------
# Solucion x para la iteracion k = 18 con error = 0.0000
# [ 0.11606437  0.56249642 -0.15178159]

# %% [markdown]
# ##  Verificación linalg Alg

# %%
from scipy.linalg import solve
print(solve(A,b))
# Out:
# [ 0.11607143  0.5625     -0.15178571]

# %% [markdown]
# ## Radio Espectral

# %%
from numpy.linalg import inv

def radio_espectral(A):
    n = np.size(A,1)
    L = np.tril(A)
    U = A-L
    T = -np.matmul(inv(L),U)
    autovalores=LA.eigvals(T)
    print("T=")
    print(T)
    print ("Autovalores = ",autovalores)
    radio_espectral=max(np.absolute(autovalores))
    print ("radio espectral =", radio_espectral)

# %%
radio_espectral(A)
# Out:
# T=
# [[-0.          0.4        -0.6       ]
#  [-0.          0.15       -0.35      ]
#  [-0.         -0.225       0.35833333]]
# Autovalores =  [-0.         -0.04516708  0.55350042]
# radio espectral = 0.5535004175943635

# %% [markdown]
# ## implementacion escalar

# %%
def gauss_seidel_es(A,b,nmax,tol):
    n = len(b)
    x = np.zeros(n)
    xnew = np.zeros(n)
    
    k=0
    error = 10
    
    while(k< nmax and tol < error):
        for i in range(n):
            S=0
            xnew[i]=x[i]
            for j in range(n):
                if i != j:
                    S+=A[i][j]*x[j]
            x[i]=(b[i]-S)/A[i][i]
            
        S=0
        for j in range(n):
            S += (xnew[j]-x[j])**2
            
        error=S**(0.5)
        print ("---------")
        print("Solucion x para la iteracion k = %2d con error = %5.4f"%(k,error))
        print(xnew)
        k+=1

# %%
gauss_seidel_es(A,b,100,1e-3)
# Out:
# ---------
# Solucion x para la iteracion k =  0 con error = 0.4706
# [0. 0. 0.]
# ---------
# Solucion x para la iteracion k =  1 con error = 0.1827
# [-0.2         0.425       0.02916667]
# ---------
# Solucion x para la iteracion k =  2 con error = 0.0922
# [-0.0475      0.47854167 -0.05600694]
# ---------
# Solucion x para la iteracion k =  3 con error = 0.0514
# [ 0.02502083  0.51638368 -0.09857436]
# ---------
# Solucion x para la iteracion k =  4 con error = 0.0284
# [ 0.06569809  0.53695858 -0.12234214]
# ---------
# Solucion x para la iteracion k =  5 con error = 0.0157
# [ 0.08818872  0.54836354 -0.13548828]
# ---------
# Solucion x para la iteracion k =  6 con error = 0.0087
# [ 0.10063838  0.55467543 -0.1427651 ]
# ---------
# Solucion x para la iteracion k =  7 con error = 0.0048
# [ 0.10752923  0.5581691  -0.1467928 ]
# ---------
# Solucion x para la iteracion k =  8 con error = 0.0027
# [ 0.11134332  0.56010284 -0.14902213]
# ---------
# Solucion x para la iteracion k =  9 con error = 0.0015
# [ 0.11345442  0.56117317 -0.15025607]
# ---------
# Solucion x para la iteracion k = 10 con error = 0.0008
# [ 0.11462291  0.5617656  -0.15093906]

# %% [markdown]
# ## Ejercicio de no convergencia

# %%
A = np.array([[1.,3.],[3.,1.]])
b= np.array([-1.,4.])
gauss_seidel_es(A,b,100,1e-5)
# Out:
# ---------
# Solucion x para la iteracion k =  0 con error = 7.0711
# [0. 0.]
# ---------
# Solucion x para la iteracion k =  1 con error = 66.4078
# [-1.  7.]
# ---------
# Solucion x para la iteracion k =  2 con error = 597.6705
# [-22.  70.]
# ---------
# Solucion x para la iteracion k =  3 con error = 5379.0343
# [-211.  637.]
# ---------
# Solucion x para la iteracion k =  4 con error = 48411.3087
# [-1912.  5740.]
# ---------
# Solucion x para la iteracion k =  5 con error = 435701.7783
# [-17221.  51667.]
# ---------
# Solucion x para la iteracion k =  6 con error = 3921316.0047
# [-155002.  465010.]
# ---------
# Solucion x para la iteracion k =  7 con error = 35291844.0419
# [-1395031.  4185097.]
# ---------
# Solucion x para la iteracion k =  8 con error = 317626596.3775
# [-12555292.  37665880.]
# ---------
# Solucion x para la iteracion k =  9 con error = 2858639367.3978
# [-1.12997641e+08  3.38992927e+08]
# ---------
# Solucion x para la iteracion k = 10 con error = 25727754306.5804
# [-1.01697878e+09  3.05093635e+09]
# ---------
# Solucion x para la iteracion k = 11 con error = 231549788759.2236
# [-9.15280905e+09  2.74584272e+10]
# ---------
# Solucion x para la iteracion k = 12 con error = 2083948098833.0122
# [-8.23752815e+10  2.47125844e+11]
# ---------
# Solucion x para la iteracion k = 13 con error = 18755532889497.1094
# [-7.41377533e+11  2.22413260e+12]
# ---------
# Solucion x para la iteracion k = 14 con error = 168799796005473.9688
# [-6.67239780e+12  2.00171934e+13]
# ---------
# Solucion x para la iteracion k = 15 con error = 1519198164049265.7500
# [-6.00515802e+13  1.80154741e+14]
# ---------
# Solucion x para la iteracion k = 16 con error = 13672783476443394.0000
# [-5.40464222e+14  1.62139267e+15]
# ---------
# Solucion x para la iteracion k = 17 con error = 123055051287990528.0000
# [-4.8641780e+15  1.4592534e+16]
# ---------
# Solucion x para la iteracion k = 18 con error = 1107495461591914880.0000
# [-4.37776020e+16  1.31332806e+17]
# ---------
# Solucion x para la iteracion k = 19 con error = 9967459154327232512.0000
# [-3.93998418e+17  1.18199525e+18]
# ---------
# Solucion x para la iteracion k = 20 con error = 89707132388945100800.0000
# [-3.54598576e+18  1.06379573e+19]
# ---------
# Solucion x para la iteracion k = 21 con error = 807364191500505972736.0000
# [-3.19138718e+19  9.57416155e+19]
# ---------
# Solucion x para la iteracion k = 22 con error = 7266277723504555065344.0000
# [-2.87224846e+20  8.61674539e+20]
# ---------
# Solucion x para la iteracion k = 23 con error = 65396499511540986150912.0000
# [-2.58502362e+21  7.75507085e+21]
# ---------
# Solucion x para la iteracion k = 24 con error = 588568495603868959244288.0000
# [-2.32652126e+22  6.97956377e+22]
# ---------
# Solucion x para la iteracion k = 25 con error = 5297116460434819895001088.0000
# [-2.09386913e+23  6.28160739e+23]
# ---------
# Solucion x para la iteracion k = 26 con error = 47674048143913384423718912.0000
# [-1.88448222e+24  5.65344665e+24]
# ---------
# Solucion x para la iteracion k = 27 con error = 429066433295220485583273984.0000
# [-1.69603400e+25  5.08810199e+25]
# ---------
# Solucion x para la iteracion k = 28 con error = 3861597899656983751774175232.0000
# [-1.52643060e+26  4.57929179e+26]
# ---------
# Solucion x para la iteracion k = 29 con error = 34754381096912855415235018752.0000
# [-1.37378754e+27  4.12136261e+27]
# ---------
# Solucion x para la iteracion k = 30 con error = 312789429872215597582045413376.0000
# [-1.23640878e+28  3.70922635e+28]
# ---------
# Solucion x para la iteracion k = 31 con error = 2815104868849940554160269164544.0000
# [-1.11276790e+29  3.33830371e+29]
# ---------
# Solucion x para la iteracion k = 32 con error = 25335943819649468928092096430080.0000
# [-1.00149111e+30  3.00447334e+30]
# ---------
# Solucion x para la iteracion k = 33 con error = 228023494376845188827631476277248.0000
# [-9.01342003e+30  2.70402601e+31]
# ---------
# Solucion x para la iteracion k = 34 con error = 2052211449391606807535074343387136.0000
# [-8.11207803e+31  2.43362341e+32]
# ---------
# Solucion x para la iteracion k = 35 con error = 18469903044524462708967549849042944.0000
# [-7.30087022e+32  2.19026107e+33]
# ---------
# Solucion x para la iteracion k = 36 con error = 166229127400720150545649893359222784.0000
# [-6.57078320e+33  1.97123496e+34]
# ---------
# Solucion x para la iteracion k = 37 con error = 1496062146606481576271777924747624448.0000
# [-5.91370488e+34  1.77411146e+35]
# ---------
# Solucion x para la iteracion k = 38 con error = 13464559319458332710706475425964490752.0000
# [-5.32233439e+35  1.59670032e+36]
# ---------
# Solucion x para la iteracion k = 39 con error = 121181033875124999118724761703325630464.0000
# [-4.79010095e+36  1.43703029e+37]
# ---------
# Solucion x para la iteracion k = 40 con error = 1090629304876124878731727266458445545472.0000
# [-4.31109086e+37  1.29332726e+38]
# ---------
# Solucion x para la iteracion k = 41 con error = 9815663743885124210817000301783303585792.0000
# [-3.87998177e+38  1.16399453e+39]
# ---------
# Solucion x para la iteracion k = 42 con error = 88340973694966115479501363486791382859776.0000
# [-3.49198359e+39  1.04759508e+40]
# ---------
# Solucion x para la iteracion k = 43 con error = 795068763254695058658325385215189241036800.0000
# [-3.14278524e+40  9.42835571e+40]
# ---------
# Solucion x para la iteracion k = 44 con error = 7155618869292255218439918645591634444550144.0000
# [-2.82850671e+41  8.48552014e+41]
# ---------
# Solucion x para la iteracion k = 45 con error = 64400569823630292014199110668803610404454400.0000
# [-2.54565604e+42  7.63696812e+42]
# ---------
# Solucion x para la iteracion k = 46 con error = 579605128412672667741873253151401290412064768.0000
# [-2.29109044e+43  6.87327131e+43]
# ---------
# Solucion x para la iteracion k = 47 con error = 5216446155714054326589509335419961987884384256.0000
# [-2.06198139e+44  6.18594418e+44]
# ---------
# Solucion x para la iteracion k = 48 con error = 46948015401426488939305584018779657890959458304.0000
# [-1.85578325e+45  5.56734976e+45]
# ---------
# Solucion x para la iteracion k = 49 con error = 422532138612838430877364661646522556939512053760.0000
# [-1.67020493e+46  5.01061478e+46]
# ---------
# Solucion x para la iteracion k = 50 con error = 3802789247515545228859174637965249446143567331328.0000
# [-1.50318444e+47  4.50955331e+47]
# ---------
# Solucion x para la iteracion k = 51 con error = 34225103227639910953955215642807966413164352897024.0000
# [-1.35286599e+48  4.05859798e+48]
# ---------
# Solucion x para la iteracion k = 52 con error = 308025929048759188201003223715616440657486517633024.0000
# [-1.21757939e+49  3.65273818e+49]
# ---------
# Solucion x para la iteracion k = 53 con error = 2772233361438832319963655198932958711721642954850304.0000
# [-1.09582145e+50  3.28746436e+50]
# ---------
# Solucion x para la iteracion k = 54 con error = 24950100252949498855040871499891865828337148275720192.0000
# [-9.86239308e+50  2.95871792e+51]
# ---------
# Solucion x para la iteracion k = 55 con error = 224550902276545479061543877219699809224577852238725120.0000
# [-8.87615377e+51  2.66284613e+52]
# ---------
# Solucion x para la iteracion k = 56 con error = 2020958120488909354089190760094606215943026599119552512.0000
# [-7.98853840e+52  2.39656152e+53]
# ---------
# Solucion x para la iteracion k = 57 con error = 18188623084400180103414313789589894382991950210857435136.0000
# [-7.18968456e+53  2.15690537e+54]
# ---------
# Solucion x para la iteracion k = 58 con error = 163697607759601631819764565576339880274914989714299682816.0000
# [-6.47071610e+54  1.94121483e+55]
# ---------
# Solucion x para la iteracion k = 59 con error = 1473278469836414686377881090187058922474234907428697145344.0000
# [-5.82364449e+55  1.74709335e+56]
# ---------
# Solucion x para la iteracion k = 60 con error = 13259506228527732003176357948163037009020315161792950042624.0000
# [-5.24128004e+56  1.57238401e+57]
# ---------
# Solucion x para la iteracion k = 61 con error = 119335556056749604754146120431434689232971540942407679868928.0000
# [-4.71715204e+57  1.41514561e+58]
# ---------
# Solucion x para la iteracion k = 62 con error = 1074020004510746375885079488291042778489589050536584600879104.0000
# [-4.24543683e+58  1.27363105e+59]
# ---------
# Solucion x para la iteracion k = 63 con error = 9666180040596720237461100806539147122978240353819534173405184.0000
# [-3.82089315e+59  1.14626795e+60]
# ---------
# Solucion x para la iteracion k = 64 con error = 86995620365370455019443745845614583999370743643968216288460800.0000
# [-3.43880384e+60  1.03164115e+61]
# ---------
# Solucion x para la iteracion k = 65 con error = 782960583288334209354809129087321740657214248755324857215877120.0000
# [-3.09492345e+61  9.28477035e+61]
# ---------
# Solucion x para la iteracion k = 66 con error = 7046645249595005965972383164975815523578585298676460416531431424.0000
# [-2.78543111e+62  8.35629332e+62]
# ---------
# Solucion x para la iteracion k = 67 con error = 63419807246355065385764547132005685341685929418352300996243226624.0000
# [-2.50688800e+63  7.52066399e+63]
# ---------
# Solucion x para la iteracion k = 68 con error = 570778265217195541703828529599157785557258717844114079976347664384.0000
# [-2.25619920e+64  6.76859759e+64]
# ---------
# Solucion x para la iteracion k = 69 con error = 5137004386954758378756780139547831829442059759123214592112204972032.0000
# [-2.03057928e+65  6.09173783e+65]
# ---------
# Solucion x para la iteracion k = 70 con error = 46233039482592825408811021255930486464978537832108931329009844748288.0000
# [-1.82752135e+66  5.48256405e+66]
# ---------
# Solucion x para la iteracion k = 71 con error = 416097355343335548405513321450941437430668336606885352175082523328512.0000
# [-1.64476921e+67  4.93430764e+67]
# ---------
# Solucion x para la iteracion k = 72 con error = 3744876198090019983540105545117499760574359627909130157661340278194176.0000
# [-1.48029229e+68  4.44087688e+68]
# ---------
# Solucion x para la iteracion k = 73 con error = 33703885782810171423135475143668776874260587324481661515886890493935616.0000
# [-1.33226306e+69  3.99678919e+69]
# ---------
# Solucion x para la iteracion k = 74 con error = 303334972045291548938201439756574425301733394521571688117938503179829248.0000
# [-1.19903676e+70  3.59711027e+70]
# ---------
# Solucion x para la iteracion k = 75 con error = 2730014748407623940443812957809169827715600550694145193061446528618463232.0000
# [-1.07913308e+71  3.23739924e+71]
# ---------
# Solucion x para la iteracion k = 76 con error = 24570132735668617033269750466952719408387760758163910763141879873574797312.0000
# [-9.71219773e+71  2.91365932e+72]
# ---------
# Solucion x para la iteracion k = 77 con error = 221131194621017537606673415735872565086016288804309156612388307702086893568.0000
# [-8.74097796e+72  2.62229339e+73]
# ---------
# Solucion x para la iteracion k = 78 con error = 1990180751589158014218909332449914473176250449053442060377447214311748403200.0000
# [-7.86688016e+73  2.36006405e+74]
# ---------
# Solucion x para la iteracion k = 79 con error = 17911626764302422127970183992049230258586254041480978543397024928805735628800.0000
# [-7.08019215e+74  2.12405764e+75]
# ---------
# Solucion x para la iteracion k = 80 con error = 161204640878721821648864275554306929914745579149605242201415137318351314878464.0000
# [-6.37217293e+75  1.91165188e+76]
# ---------
# Solucion x para la iteracion k = 81 con error = 1450841767908496060596665274118785056504595005384625855194513529044252091219968.0000
# [-5.73495564e+76  1.72048669e+77]
# ---------
# Solucion x para la iteracion k = 82 con error = 13057575911176467013626823448878128740995128884487390170854420211768063843893248.0000
# [-5.16146007e+77  1.54843802e+78]
# ---------
# Solucion x para la iteracion k = 83 con error = 117518183200588203122641411039903158668956159960386511537689781905912574595039232.0000
# [-4.64531407e+78  1.39359422e+79]
# ---------
# Solucion x para la iteracion k = 84 con error = 1057663648805294104548538329321743510055428109278363440938833463594630213921669120.0000
# [-4.18078266e+79  1.25423480e+80]
# ---------
# Solucion x para la iteracion k = 85 con error = 9518972839247645887813928278323824611318576146800947779498547166860559382185246720.0000
# [-3.76270439e+80  1.12881132e+81]
# ---------
# Solucion x para la iteracion k = 86 con error = 85670755553228806250338687717254472835113413566300861606200818866601914163764658176.0000
# [-3.38643396e+81  1.01593019e+82]
# ---------
# Solucion x para la iteracion k = 87 con error = 771036799979059350612861524482529536850573526665415112185812848691420911336517795840.0000
# [-3.04779056e+82  9.14337168e+82]
# ---------
# Solucion x para la iteracion k = 88 con error = 6939331199811533616316820377329969938314859999596122536929427187411338579956455178240.0000
# [-2.74301150e+83  8.22903451e+83]
# ---------
# Solucion x para la iteracion k = 89 con error = 62453980798303820663935543721199671461067878473556915516525896633966754521234184077312.0000
# [-2.46871035e+84  7.40613106e+84]
# ---------
# Solucion x para la iteracion k = 90 con error = 562085827184734372171927199909669468280099181707961334746515125364927680366059209097216.0000
# [-2.22183932e+85  6.66551795e+85]
# ---------
# Solucion x para la iteracion k = 91 con error = 5058772444662608686979695507292901620784329856777208577412174799927239827692207397142528.0000
# [-1.99965539e+86  5.99896616e+86]
# ---------
# Solucion x para la iteracion k = 92 con error = 45528952001963496734711439738671575211682726511639293385290490393344218726094980146790400.0000
# [-1.79968985e+87  5.39906954e+87]
# ---------
# Solucion x para la iteracion k = 93 con error = 409760568017671449410238180307432221905574529689731450537807651032670471075580405809676288.0000
# [-1.61972086e+88  4.85916259e+88]
# ---------
# Solucion x para la iteracion k = 94 con error = 3687845112159043383926780060216681277143290909847938093717177059412874199028614300470083584.0000
# [-1.45774878e+89  4.37324633e+89]
# ---------
# Solucion x para la iteracion k = 95 con error = 33190606009431388193776777625618189627668817237695742584275205533923601395601591049677438976.0000
# [-1.3119739e+90  3.9359217e+90]
# ---------
# Solucion x para la iteracion k = 96 con error = 298715454084882428610940802640203780890340287752313515794110475382495140365523314995961528320.0000
# [-1.18077651e+91  3.54232953e+91]
# ---------
# Solucion x para la iteracion k = 97 con error = 2688439086763942320666824173026615722297002624522453055226932941004712421120045866616172314624.0000
# [-1.06269886e+92  3.18809657e+92]
# ---------
# Solucion x para la iteracion k = 98 con error = 24195951780875479033327989760180414723537263481695551844722641818793387158759068672935476592640.0000
# [-9.56428972e+92  2.86928692e+93]
# ---------
# Solucion x para la iteracion k = 99 con error = 217763566027879363174807886159279282271636655227442684867456906576113174105829253601501368025088.0000
# [-8.60786075e+93  2.58235823e+94]
